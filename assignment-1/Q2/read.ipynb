# %%
import numpy as np
import pandas as pd

# %%
gbc = pd.read_csv("./titanic_pred_gbc.csv")
rfm = pd.read_csv("./titanic_pred_rfm.csv")

# %%
ex = pd.read_csv("./gender_submission.csv")

# %%
gbc
# Out:
#      PassengerId  Survived
# 0            892       0.0
# 1            893       0.0
# 2            894       0.0
# 3            895       0.0
# 4            896       1.0
# 5            897       0.0
# 6            898       0.0
# 7            899       0.0
# 8            900       1.0
# 9            901       0.0
# 10           902       0.0
# 11           903       0.0
# 12           904       1.0
# 13           905       0.0
# 14           906       1.0
# 15           907       1.0
# 16           908       0.0
# 17           909       0.0
# 18           910       1.0
# 19           911       1.0
# 20           912       0.0
# 21           913       0.0
# 22           914       1.0
# 23           915       0.0
# 24           916       1.0
# 25           917       0.0
# 26           918       1.0
# 27           919       0.0
# 28           920       0.0
# 29           921       0.0
# ..           ...       ...
# 388         1280       0.0
# 389         1281       0.0
# ...

# %%
ex.describe()
# Out:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.363636
# std     120.810458    0.481622
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000

# %%
rfm.describe()
# Out:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.363636
# std     120.810458    0.481622
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000

# %%
gbc.describe()
# Out:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.315789
# std     120.810458    0.465387
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000
